# %%
import pandas as pd
data_sampah = pd.read_csv('data_sampah.csv')
data_sampah
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3202
# 2      3             32    JAWA BARAT                 3203
# 3      4             32    JAWA BARAT                 3204
# 4      5             32    JAWA BARAT                 3205
# ..   ...            ...           ...                  ...
# 238  239             32    JAWA BARAT                 3275
# 239  240             32    JAWA BARAT                 3276
# 240  241             32    JAWA BARAT                 3277
# 241  242             32    JAWA BARAT                 3278
# 242  243             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota  jumlah_produksi_sampah        satuan  tahun
# 0       KABUPATEN BOGOR                 1511.15  TON PER HARI   2015
# 1    KABUPATEN SUKABUMI                  419.01  TON PER HARI   2015
# ...

# %%
import pandas as pd

data_sampah = pd.read_csv('data_sampah.csv')

tahun_produksi = 2015  

total_sampah_tahun_tertentu = 0

for index, row in data_sampah.iterrows():
    if row['tahun'] == tahun_produksi:
        total_sampah_tahun_tertentu += row['jumlah_produksi_sampah']

print(f'Total produksi sampah di seluruh Kabupaten/Kota di Jawa Barat pada tahun {tahun_produksi} adalah: {total_sampah_tahun_tertentu:.2f} ton')
# Out:
# Total produksi sampah di seluruh Kabupaten/Kota di Jawa Barat pada tahun 2015 adalah: 20969.27 ton

# %%
import pandas as pd

data_sampah = pd.read_csv('data_sampah.csv')

total_sampah_pertahun = {}

for index, row in data_sampah.iterrows():
    tahun = row['tahun']
    produksi = row['jumlah_produksi_sampah']
    
    if tahun in total_sampah_pertahun:
        total_sampah_pertahun[tahun] += produksi
    else:
        total_sampah_pertahun[tahun] = produksi

for tahun, total in total_sampah_pertahun.items():
    print(f'Total produksi sampah di tahun {tahun} adalah: {total:.2f} ton')
# Out:
# Total produksi sampah di tahun 2015 adalah: 20969.27 ton
# Total produksi sampah di tahun 2016 adalah: 20969.27 ton
# Total produksi sampah di tahun 2017 adalah: 20969.27 ton
# Total produksi sampah di tahun 2018 adalah: 22772.92 ton
# Total produksi sampah di tahun 2019 adalah: 24490.56 ton
# Total produksi sampah di tahun 2020 adalah: 25333.00 ton
# Total produksi sampah di tahun 2021 adalah: 15735.36 ton
# Total produksi sampah di tahun 2022 adalah: nan ton
# Total produksi sampah di tahun 2023 adalah: nan ton

# %%
import pandas as pd

data_sampah = pd.read_csv('data_sampah.csv')

total_produksi_perkota_tahun = {}

for index, row in data_sampah.iterrows():
    kota = row['nama_kabupaten_kota'] 
    tahun = row['tahun']                    
    produksi = row['jumlah_produksi_sampah']      
    
    if kota not in total_produksi_perkota_tahun:
        total_produksi_perkota_tahun[kota] = {}
    
    if tahun in total_produksi_perkota_tahun[kota]:
        total_produksi_perkota_tahun[kota][tahun] += produksi
    else:
        total_produksi_perkota_tahun[kota][tahun] = produksi

for kota_kabupaten, tahun_data in total_produksi_perkota_tahun.items():
    for tahun, total in tahun_data.items():
        print(f'Total produksi sampah di {kota_kabupaten} pada tahun {tahun} adalah: {total:.2f} ton')
# Out:
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2015 adalah: 1511.15 ton
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2016 adalah: 1511.15 ton
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2017 adalah: 1511.15 ton
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2018 adalah: 1716.80 ton
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2019 adalah: 2914.65 ton
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2020 adalah: 2977.00 ton
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2021 adalah: 971.59 ton
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2022 adalah: nan ton
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2023 adalah: nan ton
# Total produksi sampah di KABUPATEN SUKABUMI pada tahun 2015 adalah: 419.01 ton
# Total produksi sampah di KABUPATEN SUKABUMI pada tahun 2016 adalah: 419.01 ton
# Total produksi sampah di KABUPATEN SUKABUMI pada tahun 2017 adalah: 419.01 ton
# ...

# %%
import pandas as pd

data_sampah = pd.read_csv('data_sampah.csv')

tahun_produksi = 2015 

total_sampah_tahun_tertentu = 0

for index, row in data_sampah.iterrows():
    if row['tahun'] == tahun_produksi:
        total_sampah_tahun_tertentu += row['jumlah_produksi_sampah']

print(f'Total produksi sampah di seluruh Kabupaten/Kota di Jawa Barat pada tahun {tahun_produksi} adalah: {total_sampah_tahun_tertentu:.2f} ton')

hasil_tahun_tertentu = {
    'Tahun': [tahun_produksi],
    'Total Produksi Sampah (ton)': [total_sampah_tahun_tertentu]
}

df_hasil_tahun_tertentu = pd.DataFrame(hasil)

df_hasil_tahun_tertentu.to_csv('total_produksi_sampah_2015.csv', index=False)

df_hasil_tahun_tertentu.to_excel('total_produksi_sampah_2015.xlsx', index=False)

print("Hasil telah diekspor ke 'total_produksi_sampah_2015.csv' dan 'total_produksi_sampah_2015.xlsx'.")
# Out:
# Total produksi sampah di seluruh Kabupaten/Kota di Jawa Barat pada tahun 2015 adalah: 20969.27 ton
# Hasil telah diekspor ke 'total_produksi_sampah_2015.csv' dan 'total_produksi_sampah_2015.xlsx'.

# %%
import pandas as pd

data_sampah = pd.read_csv('data_sampah.csv')

total_sampah_pertahun = {}

for index, row in data_sampah.iterrows():
    tahun = row['tahun']  
    produksi = row['jumlah_produksi_sampah']  
    
    if tahun in total_sampah_pertahun:
        total_sampah_pertahun[tahun] += produksi
    else:
        total_sampah_pertahun[tahun] = produksi

for tahun, total in total_sampah_pertahun.items():
    print(f'Total produksi sampah di tahun {tahun} adalah: {total:.2f} ton')

hasil_pertahun = {
    'Tahun': list(total_sampah_pertahun.keys()),
    'Total Produksi Sampah (ton)': list(total_sampah_pertahun.values())
}

df_hasil_pertahun = pd.DataFrame(hasil)

df_hasil_pertahun.to_csv('total_produksi_sampah_per_tahun.csv', index=False)

df_hasil_pertahun.to_excel('total_produksi_sampah_per_tahun.xlsx', index=False)

print("Hasil telah diekspor ke 'total_produksi_sampah_per_tahun.csv' dan 'total_produksi_sampah_per_tahun.xlsx'.")
# Out:
# Total produksi sampah di tahun 2015 adalah: 20969.27 ton
# Total produksi sampah di tahun 2016 adalah: 20969.27 ton
# Total produksi sampah di tahun 2017 adalah: 20969.27 ton
# Total produksi sampah di tahun 2018 adalah: 22772.92 ton
# Total produksi sampah di tahun 2019 adalah: 24490.56 ton
# Total produksi sampah di tahun 2020 adalah: 25333.00 ton
# Total produksi sampah di tahun 2021 adalah: 15735.36 ton
# Total produksi sampah di tahun 2022 adalah: nan ton
# Total produksi sampah di tahun 2023 adalah: nan ton
# Hasil telah diekspor ke 'total_produksi_sampah_per_tahun.csv' dan 'total_produksi_sampah_per_tahun.xlsx'.

# %%
import pandas as pd

data_sampah = pd.read_csv('data_sampah.csv')

total_produksi_perkota_tahun = {}

for index, row in data_sampah.iterrows():
    kota = row['nama_kabupaten_kota']  
    tahun = row['tahun']                
    produksi = row['jumlah_produksi_sampah']  
    
    if kota not in total_produksi_perkota_tahun:
        total_produksi_perkota_tahun[kota] = {}
    
    if tahun in total_produksi_perkota_tahun[kota]:
        total_produksi_perkota_tahun[kota][tahun] += produksi
    else:
        total_produksi_perkota_tahun[kota][tahun] = produksi

for kota_kabupaten, tahun_data in total_produksi_perkota_tahun.items():
    for tahun, total in tahun_data.items():
        print(f'Total produksi sampah di {kota_kabupaten} pada tahun {tahun} adalah: {total:.2f} ton')

hasil_perkota_pertahun = {
    'Kota/Kabupaten': [],
    'Tahun': [],
    'Total Produksi Sampah (ton)': []
}

for kota_kabupaten, tahun_data in total_produksi_perkota_tahun.items():
    for tahun, total in tahun_data.items():
        hasil_perkota_pertahun['Kota/Kabupaten'].append(kota_kabupaten)
        hasil_perkota_pertahun['Tahun'].append(tahun)
        hasil_perkota_pertahun['Total Produksi Sampah (ton)'].append(total)

df_hasil_perkota_pertahun = pd.DataFrame(hasil)

df_hasil_perkota_pertahun.to_csv('total_produksi_sampah_perkota_tahun.csv', index=False)

df_hasil_perkota_pertahun.to_excel('total_produksi_sampah_perkota_tahun.xlsx', index=False)

print("Hasil telah diekspor ke 'total_produksi_sampah_per_kota_tahun.csv' dan 'total_produksi_sampah_per_kota_tahun.xlsx'.")
# Out:
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2015 adalah: 1511.15 ton
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2016 adalah: 1511.15 ton
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2017 adalah: 1511.15 ton
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2018 adalah: 1716.80 ton
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2019 adalah: 2914.65 ton
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2020 adalah: 2977.00 ton
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2021 adalah: 971.59 ton
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2022 adalah: nan ton
# Total produksi sampah di KABUPATEN BOGOR pada tahun 2023 adalah: nan ton
# Total produksi sampah di KABUPATEN SUKABUMI pada tahun 2015 adalah: 419.01 ton
# Total produksi sampah di KABUPATEN SUKABUMI pada tahun 2016 adalah: 419.01 ton
# Total produksi sampah di KABUPATEN SUKABUMI pada tahun 2017 adalah: 419.01 ton
# ...
